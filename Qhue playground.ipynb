# %% [markdown]
# # Qhue experiments
#
# Experiments with the [Qhue](https://github.com/quentinsf/qhue) python module.
#
# If you haven't already, then `pip install qhue` before starting.
#
# Some of these examples may assume you have a recent bridge with recent software.

# %% [markdown]
# ## Basics

# %%
# Put in the IP address of your Hue bridge here
BRIDGE_IP='192.168.0.45'

from qhue import Bridge, QhueException, create_new_username

# %%
# If you have a username set up on your bridge, enter it here
# otherwise leave it as None and you'll be prompted to create one.
# e.g.:
# username='zeZomfNu-y-p1PLM9oeYTiXbtqsxn-q1-7RNLI4B'

username=None

if username is None:
    username = create_new_username(BRIDGE_IP)
    print "New user: {} . Put this in the username variable above.".format(username)

# %% [markdown]
# Let's get the numbers and names of the lights:

# %%
bridge = Bridge(BRIDGE_IP, username)
lights = bridge.lights()
for num, info in lights.items():
    print "{:16} {}".format(info['name'], num)
# Out:
# Kitchen table    11
# Mantlepiece R    24
# Shed             23
# Kitchen          12
# Picture rail     15
# Sitting room 2   14
# Dining table 1   17
# Dining table 3   16
# Dining table 2   18
# Bedroom 1        22
# Kitchen Sink     3
# Top Landing      5
# Landing          4
# Front hall 1     7
# Kitchen Stove    6
# Front hall 2     8
# Mantlepiece L    25
# Sitting room 1   21

# %% [markdown]
# Let's try interactively changing a light.  You could make this a lot more sophisticated:

# %%
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

def setlight(lightid='14', on=True, ct=128, bri=128):
    bridge.lights[lightid].state(on=on)
    if on:
        bridge.lights[lightid].state(bri=bri, ct=ct)

light_list = interact(setlight,
                      lightid = widgets.Dropdown(
                            options={ lights[i]['name']:i for i in lights },
                            value='14',
                            description='Light:',
                        ),
                      on = widgets.Checkbox(value=True, description='On/off'),
                      bri = widgets.IntSlider(min=0,max=255,value=128, description='Bright:'),
                      ct = widgets.IntSlider(min=0,max=255,value=128, description='Colour:'))

# %% [markdown]
# The [YAML format](https://en.wikipedia.org/wiki/YAML) is a nice way to view the sometimes large amount of structured information which comes back from the bridge.
#
# If you haven't got the Python yaml module, `pip install PyYAML`.

# %%
import yaml
print len(lights), "lights\n"
print yaml.safe_dump(lights, indent=4)
# Out:
# 18 lights
#
# '11':
#     manufacturername: Philips
#     modelid: LCT007
#     name: Kitchen table
#     state:
#         alert: none
#         bri: 254
#         colormode: xy
#         ct: 223
#         effect: none
#         hue: 33910
#         'on': false
#         reachable: true
#         sat: 71
#         xy: [0.3622, 0.3646]
#     swversion: 5.38.1.14919
#     type: Extended color light
#     uniqueid: 00:17:88:01:00:f7:e8:58-0b
# '12':
#     manufacturername: Philips
#     modelid: LCT007
#     name: Kitchen
#     state:
#         alert: none
#         bri: 254
#         colormode: xy
#         ct: 239
#         effect: none
#         hue: 33810
#         'on': false
#         reachable: true
#         sat: 28
#         xy: [0.3734, 0.3722]
#     swversion: 5.38.1.14919
#     type: Extended color light
#     uniqueid: 00:17:88:01:00:f6:e4:98-0b
# '14':
#     manufacturername: Philips
#     modelid: LCT001
#     name: Sitting room 2
#     state:
#         alert: none
#         bri: 189
#         colormode: xy
#         ct: 463
#         effect: none
#         hue: 3941
#         'on': false
#         reachable: true
#         sat: 130
#         xy: [0.5102, 0.3642]
#     swversion: 5.23.1.13452
#     type: Extended color light
#     uniqueid: 00:17:88:01:00:ff:18:38-0b
# '15':
#     manufacturername: Philips
#     modelid: LST002
#     name: Picture rail
#     state:
#         alert: none
#         bri: 254
#         colormode: xy
#         ct: 239
#         effect: none
#         hue: 40998
#         'on': false
#         reachable: true
#         sat: 8
#         xy: [0.3734, 0.3723]
#     swversion: 5.50.1.15744
#     type: Extended color light
#     uniqueid: 00:17:88:01:01:1a:76:44-0b
# '16':
#     manufacturername: Philips
#     modelid: LCT003
#     name: Dining table 3
#     state:
#         alert: none
#         bri: 254
#         colormode: xy
#         ct: 262
#         effect: none
#         hue: 16620
#         'on': false
#         reachable: true
#         sat: 18
#         xy: [0.389, 0.3819]
#     swversion: 5.23.1.13105
#     type: Extended color light
#     uniqueid: 00:17:88:01:10:35:1c:22-0b
# '17':
#     manufacturername: Philips
#     modelid: LCT003
#     name: Dining table 1
#     state:
#         alert: none
#         bri: 254
#         colormode: xy
#         ct: 226
#         effect: none
#         hue: 33882
#         'on': false
#         reachable: true
#         sat: 61
#         xy: [0.3649, 0.3665]
#     swversion: 5.23.1.13105
#     type: Extended color light
#     uniqueid: 00:17:88:01:00:e9:38:a3-0b
# '18':
#     manufacturername: Philips
#     modelid: LCT003
#     name: Dining table 2
#     state:
#         alert: none
#         bri: 254
#         colormode: xy
#         ct: 262
#         effect: none
#         hue: 16620
#         'on': false
#         reachable: true
#         sat: 18
#         xy: [0.389, 0.3819]
#     swversion: 5.23.1.13105
#     type: Extended color light
#     uniqueid: 00:17:88:01:10:35:00:ce-0b
# '21':
#     manufacturername: Philips
#     modelid: LCT001
#     name: Sitting room 1
#     state:
#         alert: none
#         bri: 189
#         colormode: ct
#         ct: 253
#         effect: none
#         hue: 16561
#         'on': false
#         reachable: true
#         sat: 6
#         xy: [0.3833, 0.3785]
#     swversion: 5.23.1.13452
#     type: Extended color light
#     uniqueid: 00:17:88:01:00:fc:d0:6e-0b
# '22':
#     manufacturername: Philips
#     modelid: LTW001
#     name: Bedroom 1
#     state: {alert: none, bri: 254, colormode: ct, ct: 366, 'on': true, reachable: false}
#     swversion: 5.50.1.16698
#     type: Color temperature light
#     uniqueid: 00:17:88:01:10:2e:97:4b-0b
# '23':
#     manufacturername: Philips
#     modelid: LWB006
#     name: Shed
#     state: {alert: none, bri: 254, 'on': false, reachable: true}
#     swversion: 5.38.1.15095
#     type: Dimmable light
#     uniqueid: 00:17:88:01:10:40:e4:54-0b
# '24':
#     manufacturername: OSRAM
#     modelid: Classic B40 TW - LIGHTIFY
#     name: Mantlepiece R
#     state: {alert: select, bri: 1, colormode: ct, ct: 370, 'on': false, reachable: true}
#     swversion: V1.03.20
#     type: Color temperature light
#     uniqueid: 84:18:26:00:00:09:59:e3-03
# '25':
#     manufacturername: OSRAM
#     modelid: Classic B40 TW - LIGHTIFY
#     name: Mantlepiece L
#     state: {alert: select, bri: 1, colormode: ct, ct: 370, 'on': false, reachable: true}
#     swversion: V1.03.20
#     type: Color temperature light
#     uniqueid: 84:18:26:00:00:09:5a:71-03
# '3':
#     manufacturername: Philips
#     modelid: LCT001
#     name: Kitchen Sink
#     state:
#         alert: none
#         bri: 254
#         colormode: xy
#         ct: 226
#         effect: none
#         hue: 33882
#         'on': false
#         reachable: true
#         sat: 61
#         xy: [0.3649, 0.3665]
#     swversion: 5.23.1.13452
#     type: Extended color light
#     uniqueid: 00:17:88:01:00:d3:13:6c-0b
# '4':
#     manufacturername: Philips
#     modelid: LCT001
#     name: Landing
#     state:
#         alert: none
#         bri: 41
#         colormode: xy
#         ct: 500
#         effect: none
#         hue: 11413
#         'on': false
#         reachable: true
#         sat: 252
#         xy: [0.555, 0.4091]
#     swversion: 5.23.1.13452
#     type: Extended color light
#     uniqueid: 00:17:88:01:00:ff:68:65-0b
# '5':
#     manufacturername: Philips
#     modelid: LCT001
#     name: Top Landing
#     state:
#         alert: none
#         bri: 52
#         colormode: xy
#         ct: 500
#         effect: none
#         hue: 6369
#         'on': false
#         reachable: true
#         sat: 252
#         xy: [0.607, 0.3708]
#     swversion: 5.23.1.13452
#     type: Extended color light
#     uniqueid: 00:17:88:01:00:fd:27:d8-0b
# '6':
#     manufacturername: Philips
#     modelid: LCT001
#     name: Kitchen Stove
#     state:
#         alert: none
#         bri: 254
#         colormode: xy
#         ct: 262
#         effect: none
#         hue: 16620
#         'on': false
#         reachable: true
#         sat: 18
#         xy: [0.389, 0.3819]
#     swversion: 5.23.1.13452
#     type: Extended color light
#     uniqueid: 00:17:88:01:00:d3:6b:26-0b
# '7':
#     manufacturername: Philips
#     modelid: LCT001
#     name: Front hall 1
#     state:
#         alert: none
#         bri: 144
#         colormode: xy
#         ct: 443
#         effect: none
#         hue: 13524
#         'on': false
#         reachable: true
#         sat: 200
#         xy: [0.5017, 0.4152]
#     swversion: 5.23.1.13452
#     type: Extended color light
#     uniqueid: 00:17:88:01:00:d1:27:95-0b
# '8':
#     manufacturername: Philips
#     modelid: LCT001
#     name: Front hall 2
#     state:
#         alert: none
#         bri: 144
#         colormode: xy
#         ct: 443
#         effect: none
#         hue: 13524
#         'on': false
#         reachable: true
#         sat: 200
#         xy: [0.5017, 0.4152]
#     swversion: 5.23.1.13452
#     type: Extended color light
#     uniqueid: 00:17:88:01:00:d1:28:3a-0b

# %%
print yaml.safe_dump(bridge.lights['24'](), indent=4)
# Out:
# manufacturername: OSRAM
# modelid: Classic B40 TW - LIGHTIFY
# name: Mantlepiece R
# state: {alert: select, bri: 1, colormode: ct, ct: 370, 'on': false, reachable: true}
# swversion: V1.03.20
# type: Color temperature light
# uniqueid: 84:18:26:00:00:09:59:e3-03

# %% [markdown]
# ## Scenes

# %% [markdown]
# Let's look at the scenes defined in the bridge, and their IDs.  Some of these may be created manually, and others by the Hue app or other software.
#
# Version 1-type scenes just refer to the lights - each light is told: "Set the value you have stored for this scene".
#
# Version 2 scenes have more details stored in the hub, which is generally more useful.

# %%
scenes = bridge.scenes()
print len(scenes), "scenes\n"
print yaml.safe_dump(scenes, indent=4)
# Out:
# 133 scenes
#
# -1iru0uZghuPUgV:
#     appdata: {data: 3dS2m_r04_d03, version: 1}
#     lastupdated: '2016-07-23T10:42:48'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Concentrate
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# 06869458c-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '7', '8']
#     locked: false
#     name: Bright hall land
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 07981a34a-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '5']
#     locked: true
#     name: 'Warm landing on '
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 0d9qlRyOk7Td5-0:
#     appdata: {data: PcOcf_r07_d06, version: 1}
#     lastupdated: '2016-04-29T07:54:46'
#     lights: ['7', '8']
#     locked: false
#     name: Dimmed
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# 0f7797c16-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '6', '7', '8', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Dining on 0
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 1204e3dd0-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: 'Warm kitchen on '
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 12490b126-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['7', '8']
#     locked: false
#     name: Warm hall on 0
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 16c1f1a5b-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '5']
#     locked: false
#     name: Spring landing o
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# '199':
#     appdata: {}
#     lastupdated: null
#     lights: ['7', '8']
#     locked: false
#     name: automatic
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 1c0d0ffc2-on-0:
#     appdata: {}
#     lastupdated: '2016-01-05T18:54:10'
#     lights: ['3']
#     locked: false
#     name: 'Venice night on '
#     owner: fIFHQxPjuUiAIWL7
#     picture: ''
#     recycle: true
#     version: 1
# 1f81613a2-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4']
#     locked: false
#     name: Spring landing o
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 1fbeb00c8-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4']
#     locked: false
#     name: Landing low glow
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 204f5998d-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '5']
#     locked: false
#     name: Spring landing o
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 204f5998d-on-15:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '5']
#     locked: true
#     name: Spring landing o
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 2HASTwKUVsTGD7l:
#     appdata: {data: PmH2Z_r08_d19, version: 1}
#     lastupdated: '2016-07-23T11:48:50'
#     lights: ['4', '5']
#     locked: true
#     name: 'Off'
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# 2ed6203cf-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['7', '8']
#     locked: false
#     name: Warm hall on 0
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 342dc4014-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '5']
#     locked: false
#     name: Landing low glow
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 351acdcd6-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['7', '8']
#     locked: true
#     name: Hall low glow on
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 357d74e5d-on-0:
#     appdata: {}
#     lastupdated: '2016-01-05T18:54:46'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Cozy dinner on 0
#     owner: fIFHQxPjuUiAIWL7
#     picture: ''
#     recycle: true
#     version: 1
# 36bc44da7-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4']
#     locked: false
#     name: 'Warm landing on '
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 3jOcNGuX09DIzrl:
#     appdata: {data: hlq6R_r07_d03, version: 1}
#     lastupdated: '2016-07-23T10:43:36'
#     lights: ['7', '8']
#     locked: true
#     name: Concentrate
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# 3owQUn01W7nVsxR:
#     appdata: {data: mdVDQ_r06_d99, version: 1}
#     lastupdated: '2016-08-07T10:19:47'
#     lights: ['14', '21', '24', '25']
#     locked: true
#     name: Evening
#     owner: zeQomfNu-w-p1PLM8oeYTiXbtqsxn-q1-7MLIN4B
#     picture: ''
#     recycle: false
#     version: 2
# 466675cc0-on-0:
#     appdata: {}
#     lastupdated: '2016-01-05T18:51:32'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Kitchen low glow
#     owner: fIFHQxPjuUiAIWL7
#     picture: ''
#     recycle: true
#     version: 1
# 47afc46c7-off-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['14']
#     locked: false
#     name: 2 lights off
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 4a824b584-on-0:
#     appdata: {}
#     lastupdated: '2016-01-05T18:53:18'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Kitchen low glow
#     owner: fIFHQxPjuUiAIWL7
#     picture: ''
#     recycle: true
#     version: 1
# 4fa96f167-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['14']
#     locked: false
#     name: Afternoon sittin
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 50e86426a-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: true
#     name: Kitchen low glow
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 54098dd13-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['14']
#     locked: false
#     name: Laila on 0
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 597ab7b48-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: 'Warm kitchen on '
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 5kRjH0acnrfATBO:
#     appdata: {data: ZDSh8_r04_d01, version: 1}
#     lastupdated: '2016-07-23T10:42:45'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Relax
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# 67f767f32-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['7', '8']
#     locked: false
#     name: Automatic on 0
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 6N9am9oJ6hFdf2n:
#     appdata: {data: 9uLJ3_r08_d05, version: 1}
#     lastupdated: '2016-07-23T11:48:50'
#     lights: ['4', '5']
#     locked: true
#     name: Bright
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# 6VRh7MuKX1Nheu3:
#     appdata: {data: 9ZKPl_r08_d03, version: 1}
#     lastupdated: '2016-07-23T10:43:38'
#     lights: ['4', '5']
#     locked: true
#     name: Concentrate
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# 71616ef01-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['7', '8']
#     locked: false
#     name: Bright hall on 0
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 7264de849-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['7', '8']
#     locked: false
#     name: Hall low glow on
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 73736188f-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Bright kitchen o
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 738e3c2af-off-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '5']
#     locked: false
#     name: 2 lights off
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 77470a3f5-off-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['7', '8']
#     locked: false
#     name: 2 lights off
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 80236015d-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '6', '11', '12', '15']
#     locked: false
#     name: Cozy dinner on 0
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 80bfa951a-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Cozy dinner on 0
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 81f2efa93-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['14']
#     locked: false
#     name: Warm sitting roo
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 8803a55c4-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '6', '7', '8', '11', '12', '15']
#     locked: false
#     name: Dining on 0
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 88ae2be2b-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '5']
#     locked: false
#     name: Spring landing o
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 88ae2be2b-on-15:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '5']
#     locked: false
#     name: Spring landing o
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 88ae2be2b-on-30:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '5']
#     locked: false
#     name: Spring landing o
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 8ZOkB2fE0pxfCFl:
#     appdata: {data: rq3N7_r07_d01, version: 1}
#     lastupdated: '2016-07-23T10:43:35'
#     lights: ['7', '8']
#     locked: true
#     name: Relax
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# 9812cefa8-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '6']
#     locked: true
#     name: 'Warm kitchen on '
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 983ab6c2c-on-3:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '4', '5', '6', '7', '8']
#     locked: true
#     name: Low glow on 3
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# 9fb67981f-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['7', '8']
#     locked: false
#     name: Bright hall on 0
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# A9gvqmtnq8IIsYl:
#     appdata: {data: YBP0W_r09_d99, version: 1}
#     lastupdated: '2016-05-02T20:36:28'
#     lights: ['22']
#     locked: false
#     name: Morning
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# AR-I2sRzlFCgcC5:
#     appdata: {data: T01lg_r09_d04, version: 1}
#     lastupdated: '2016-05-02T20:29:45'
#     lights: ['22']
#     locked: false
#     name: Energize
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# Af7YZIGnPJCMNkL:
#     appdata: {data: 4kN8E_r07_d04, version: 1}
#     lastupdated: '2016-07-23T10:43:37'
#     lights: ['7', '8']
#     locked: true
#     name: Energize
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# AsptFt3pCldMO21:
#     appdata: {data: WBc8j_r07_d20, version: 1}
#     lastupdated: '2016-07-23T10:43:34'
#     lights: ['7', '8']
#     locked: true
#     name: Last on state
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# AxbidVtIKaLcaP9:
#     appdata: {data: WSPtu_r07_d99, version: 1}
#     lastupdated: '2016-04-29T08:43:51'
#     lights: ['7', '8']
#     locked: false
#     name: Warm
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# Bwi-oM7y8oRtKBY:
#     appdata: {data: Tim9d_r08_d01, version: 1}
#     lastupdated: '2016-07-23T10:43:37'
#     lights: ['4', '5']
#     locked: true
#     name: Relax
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# CEt-2DBYBs2YmHV:
#     appdata: {data: VFg2O_r04_d20, version: 1}
#     lastupdated: '2016-07-23T10:42:44'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Last on state
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# EZJc3EGonto7WIN:
#     appdata: {data: nW5It_r05_d07, version: 1}
#     lastupdated: '2016-07-23T10:31:49'
#     lights: ['23']
#     locked: false
#     name: Nightlight
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# FZxR8JD7npo7yvJ:
#     appdata: {data: umucl_r04_d06, version: 1}
#     lastupdated: '2016-04-29T09:01:20'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Dimmed
#     owner: s4zx5V9P01QX2tXIQpntlzfzVHfLpBLscIGWgfqP
#     picture: ''
#     recycle: false
#     version: 2
# I6Gwi3XEvtVveHO:
#     appdata: {data: L1TwL_r05_d05, version: 1}
#     lastupdated: '2016-07-23T10:31:49'
#     lights: ['23']
#     locked: false
#     name: Bright
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# IB57U3scrj4cQWk:
#     appdata: {data: lkGxN_r06_d02, version: 1}
#     lastupdated: '2016-08-06T18:25:58'
#     lights: ['14', '21', '24', '25']
#     locked: false
#     name: Read
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# JFb70MR1pTrdTd1:
#     appdata: {data: Oh3Sw_r08_d06, version: 1}
#     lastupdated: '2016-04-29T07:55:47'
#     lights: ['4', '5']
#     locked: true
#     name: Dimmed
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# JtK7kjbIM6FQbpi:
#     appdata: {data: SGpJ6_r09_d99, version: 1}
#     lastupdated: '2016-05-02T20:35:58'
#     lights: ['22']
#     locked: false
#     name: Evening
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# KFtoQ3-VRkdgALV:
#     appdata: {data: M5ulg_r08_d99, version: 1}
#     lastupdated: '2016-04-29T08:48:16'
#     lights: ['4', '5']
#     locked: true
#     name: Warm
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# KZNM2DZmdcydRIc:
#     appdata: {data: 'D80D35E2:AA00000', version: 1}
#     lastupdated: '2016-08-06T23:50:55'
#     lights: ['14', '21', '24', '25']
#     locked: false
#     name: All warm
#     owner: 340b58942b336b4f883cabc310ff4b7
#     picture: ''
#     recycle: false
#     version: 2
# N27vS4xRFx41Vxm:
#     appdata: {data: CYTK2_r04_d07, version: 1}
#     lastupdated: '2016-04-29T09:01:21'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Nightlight
#     owner: s4zx5V9P01QX2tXIQpntlzfzVHfLpBLscIGWgfqP
#     picture: ''
#     recycle: false
#     version: 2
# ON-DIMMER:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '4', '5', '6', '7', '8', '11', '12', '14', '15', '16', '17', '18']
#     locked: false
#     name: Dimmer scene
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# PvF0e3fVxnOekkk:
#     appdata: {data: ntNgZ_r09_d02, version: 1}
#     lastupdated: '2016-05-02T20:29:45'
#     lights: ['22']
#     locked: false
#     name: Read
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# QnxaMuiruvrYmvI:
#     appdata: {data: ODtPS_r08_d04, version: 1}
#     lastupdated: '2016-07-23T10:43:38'
#     lights: ['4', '5']
#     locked: true
#     name: Energize
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# Rb2sR3LlDBaBlo2:
#     appdata: {data: 3dS2m_r04_d03, version: 1}
#     lastupdated: '2016-07-23T10:56:00'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: true
#     name: Concentrate
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# RdOEaZplFDGXVZB:
#     appdata: {data: PmH2Z_r08_d19, version: 1}
#     lastupdated: '2016-04-29T08:54:08'
#     lights: ['4', '5']
#     locked: true
#     name: 'Off'
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# RrwQruSI7ErLfTy:
#     appdata: {data: 25C75_r09_d05, version: 1}
#     lastupdated: '2016-05-02T20:29:46'
#     lights: ['22']
#     locked: false
#     name: Bright
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# SUThT3XiV7sSzml:
#     appdata: {data: VKza7_r06_d99, version: 1}
#     lastupdated: '2016-08-07T10:19:18'
#     lights: ['14', '21', '24', '25']
#     locked: true
#     name: Warm
#     owner: zeQomfNu-w-p1PLM8oeYTiXbtqsxn-q1-7MLIN4B
#     picture: ''
#     recycle: false
#     version: 2
# SePln7Lt9-H7Hm7:
#     appdata: {data: XdAUW_r06_d99, version: 1}
#     lastupdated: '2016-08-07T09:35:44'
#     lights: ['14', '21', '24', '25']
#     locked: true
#     name: Bright
#     owner: zeQomfNu-w-p1PLM8oeYTiXbtqsxn-q1-7MLIN4B
#     picture: ''
#     recycle: false
#     version: 2
# T6UzpfPUK2kmvu7:
#     appdata: {data: JeRbp_r04_d04, version: 1}
#     lastupdated: '2016-07-23T10:42:49'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Energize
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# VaknVPkUZnSrdiB:
#     appdata: {data: qOjSB_r06_d99, version: 1}
#     lastupdated: '2016-08-06T18:39:00'
#     lights: ['14', '21', '24', '25']
#     locked: false
#     name: Bright
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# WOZVY1DKAc6MjKx:
#     appdata: {data: vFHN7_r04_d99, version: 1}
#     lastupdated: '2016-04-29T09:01:22'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: true
#     name: Warm
#     owner: s4zx5V9P01QX2tXIQpntlzfzVHfLpBLscIGWgfqP
#     picture: ''
#     recycle: false
#     version: 2
# Wny1y4JoTVmZJo3:
#     appdata: {data: JeRbp_r04_d04, version: 1}
#     lastupdated: '2016-07-23T10:56:01'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: true
#     name: Energize
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# XM3CA6IR2l0YiHv:
#     appdata: {data: 8tyNJ_r09_d01, version: 1}
#     lastupdated: '2016-05-02T20:29:45'
#     lights: ['22']
#     locked: false
#     name: Relax
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# YDfVlYFWoaL6yv5:
#     appdata: {data: ta8ou_r06_d07, version: 1}
#     lastupdated: '2016-08-06T18:25:59'
#     lights: ['14', '21', '24', '25']
#     locked: false
#     name: Nightlight
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# YS2bpqTvC-9x7vI:
#     appdata: {data: CRYrn_r04_d99, version: 1}
#     lastupdated: '2016-05-10T19:33:34'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Cozy white
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# a178eb5a3-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['7', '8']
#     locked: false
#     name: Warm hall on 0
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# a38572fca-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: true
#     name: Bright kitchen o
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# a49b85109-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '7', '8']
#     locked: true
#     name: Bright hall land
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# a4fe6838e-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4']
#     locked: false
#     name: Spring landing o
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# a9e5a4ab6-on-0:
#     appdata: {}
#     lastupdated: '2016-01-05T18:54:29'
#     lights: ['3', '6', '11', '12']
#     locked: false
#     name: Winter kitchen o
#     owner: fIFHQxPjuUiAIWL7
#     picture: ''
#     recycle: true
#     version: 1
# ac7654efb-off-1:
#     appdata: {}
#     lastupdated: '2016-04-13T23:59:00'
#     lights: ['3', '4', '5', '6', '7', '8', '11', '12', '14', '15', '16', '17', '18']
#     locked: true
#     name: 14 lights off
#     owner: eYXkeVdweVI6FZIW
#     picture: ''
#     recycle: true
#     version: 1
# b17e9e626-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3']
#     locked: false
#     name: Beach on 0
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# b19033822-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '5']
#     locked: false
#     name: Landing low glow
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# bd6b33115-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['14']
#     locked: false
#     name: Bright sitting r
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# be67e9401-off-2:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '4', '5', '6', '7', '8']
#     locked: false
#     name: 10 lights off
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# befd0fc82-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '6']
#     locked: false
#     name: Winter kitchen o
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# c1dcf5510-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '7', '8']
#     locked: false
#     name: Warm hall landin
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# cd06c70f7-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['14']
#     locked: false
#     name: Warm sitting roo
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# cff986e21-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '5']
#     locked: false
#     name: Spring landing o
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# cff986e21-on-15:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '5']
#     locked: false
#     name: Spring landing o
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# cxi4y-uCBKoV-Yd:
#     appdata: {data: ZDSh8_r04_d01, version: 1}
#     lastupdated: '2016-07-23T10:55:57'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: true
#     name: Relax
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# d3a196d65-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: true
#     name: 'Warm kitchen on '
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# d593b938b-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '5']
#     locked: false
#     name: Landing low glow
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# d85f96e2f-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4']
#     locked: false
#     name: 'Warm landing on '
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# dc93a70b8-off-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: true
#     name: 10 lights off
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# e21m6w2kNoxYdXQ:
#     appdata: {data: eKXs0_r09_d03, version: 1}
#     lastupdated: '2016-05-02T20:29:45'
#     lights: ['22']
#     locked: false
#     name: Concentrate
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# eIgizpH1k6lP3TN:
#     appdata: {data: IcjCm_r04_d99, version: 1}
#     lastupdated: '2016-04-29T09:01:23'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: true
#     name: Bright
#     owner: s4zx5V9P01QX2tXIQpntlzfzVHfLpBLscIGWgfqP
#     picture: ''
#     recycle: false
#     version: 2
# eb0d9d166-off-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '6', '11', '12', '16', '17', '18']
#     locked: false
#     name: 7 lights off
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# ee511YI2hWHJ5L3:
#     appdata: {data: nHTkL_r09_d07, version: 1}
#     lastupdated: '2016-05-02T20:29:46'
#     lights: ['22']
#     locked: false
#     name: Nightlight
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# ef2edea8e-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['3', '6', '11', '12', '15']
#     locked: false
#     name: Kitchen low glow
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# efcaf527a-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '7', '8']
#     locked: true
#     name: Warm hall landin
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# efcdee1f3-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '5']
#     locked: false
#     name: Spring landing o
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# efcdee1f3-on-15:
#     appdata: {}
#     lastupdated: null
#     lights: ['4', '5']
#     locked: false
#     name: Spring landing o
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# f6af64acc-off-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['7', '8']
#     locked: true
#     name: 4 lights off
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# fW9vVvd9InLN2ND:
#     appdata: {data: pYVR5_r09_d06, version: 1}
#     lastupdated: '2016-05-02T20:29:46'
#     lights: ['22']
#     locked: false
#     name: Dimmed
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# fd2a7188f-on-0:
#     appdata: {}
#     lastupdated: '2016-01-05T18:54:53'
#     lights: ['3', '6', '7', '8', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Dining on 0
#     owner: fIFHQxPjuUiAIWL7
#     picture: ''
#     recycle: true
#     version: 1
# ff2dd0ec0-on-0:
#     appdata: {}
#     lastupdated: null
#     lights: ['14']
#     locked: false
#     name: Afternoon Sittin
#     owner: none
#     picture: ''
#     recycle: true
#     version: 1
# g7tDrSN6Hpofhfj:
#     appdata: {data: X0BrF_r04_d99, version: 1}
#     lastupdated: '2016-04-29T09:01:22'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: true
#     name: Low glow
#     owner: s4zx5V9P01QX2tXIQpntlzfzVHfLpBLscIGWgfqP
#     picture: ''
#     recycle: false
#     version: 2
# gZ5lkJ6N8lxPcQ8:
#     appdata: {data: 59C1C_r08_d02, version: 1}
#     lastupdated: '2016-07-23T10:43:38'
#     lights: ['4', '5']
#     locked: true
#     name: Read
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# in-NXNYKlDikoMa:
#     appdata: {data: qojkY_r08_d18, version: 1}
#     lastupdated: '2016-04-29T07:55:48'
#     lights: ['4', '5']
#     locked: false
#     name: Spring blossom
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# jK3AIIkFATelYSp:
#     appdata: {data: Z74NA_r08_d99, version: 1}
#     lastupdated: '2016-04-29T08:47:17'
#     lights: ['4', '5']
#     locked: true
#     name: Bright
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# jvY8sFPTjjgEUWo:
#     appdata: {data: R1Iyd_r05_d06, version: 1}
#     lastupdated: '2016-07-23T10:31:49'
#     lights: ['23']
#     locked: false
#     name: Dimmed
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# mSrWSm46uuU0yZg:
#     appdata: {data: NuGgn_r04_d99, version: 1}
#     lastupdated: '2016-05-10T19:32:17'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Cozy dining
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# o3EjXJ2eZJVt-Yp:
#     appdata: {data: gG94t_r07_d99, version: 1}
#     lastupdated: '2016-04-29T08:44:50'
#     lights: ['7', '8']
#     locked: false
#     name: Bright
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# pIClVVDfAj2awSK:
#     appdata: {data: zPEfm_r04_d02, version: 1}
#     lastupdated: '2016-07-23T10:42:46'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: false
#     name: Read
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# qnLLDH8uKdhkKXR:
#     appdata: {data: VFg2O_r04_d20, version: 1}
#     lastupdated: '2016-07-23T10:55:56'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: true
#     name: Last on state
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# qusSD82UJv6OIE6:
#     appdata: {data: lPXO1_r08_d99, version: 1}
#     lastupdated: '2016-04-29T08:48:43'
#     lights: ['4', '5']
#     locked: true
#     name: Low glow
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# r385fUT49aGqrQK:
#     appdata: {data: g0sko_r04_d19, version: 1}
#     lastupdated: '2016-04-29T09:26:43'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: true
#     name: 'Off'
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# uTiCStN5kNYX9KM:
#     appdata: {data: plqgS_r07_d99, version: 1}
#     lastupdated: '2016-04-29T08:46:12'
#     lights: ['7', '8']
#     locked: false
#     name: Low glow
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# v4rVpTBw3Jj2Msq:
#     appdata: {data: PmH2Z_r08_d19, version: 1}
#     lastupdated: '2016-04-29T08:52:37'
#     lights: ['4', '5']
#     locked: true
#     name: 'Off'
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# vljsBHKjn0LCnfB:
#     appdata: {data: 3PG9h_r07_d07, version: 1}
#     lastupdated: '2016-04-29T07:54:46'
#     lights: ['7', '8']
#     locked: false
#     name: Nightlight
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# wG25IXpcHHTim4g:
#     appdata: {data: yyqNT_r06_d19, version: 1}
#     lastupdated: '2016-08-06T18:26:02'
#     lights: ['14', '21', '24', '25']
#     locked: true
#     name: 'Off'
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# wVXtOrFmdnySqUz:
#     appdata: {data: skbwq_r06_d06, version: 1}
#     lastupdated: '2016-08-06T18:25:59'
#     lights: ['14', '21', '24', '25']
#     locked: false
#     name: Dimmed
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2
# xNSvFQPy3S-8G4I:
#     appdata: {data: yzXxH_r07_d02, version: 1}
#     lastupdated: '2016-07-23T10:43:36'
#     lights: ['7', '8']
#     locked: true
#     name: Read
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# y8S9t3NMudgmOai:
#     appdata: {data: zPEfm_r04_d02, version: 1}
#     lastupdated: '2016-07-23T10:55:58'
#     lights: ['3', '6', '11', '12', '15', '16', '17', '18']
#     locked: true
#     name: Read
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# z7c8bEBWcHBYGA2:
#     appdata: {data: PmH2Z_r08_d19, version: 1}
#     lastupdated: '2016-04-29T08:51:26'
#     lights: ['4', '5']
#     locked: true
#     name: 'Off'
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# zifBdqd-uYwto1C:
#     appdata: {data: ojZfb_r08_d20, version: 1}
#     lastupdated: '2016-07-23T10:43:37'
#     lights: ['4', '5']
#     locked: true
#     name: Last on state
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: true
#     version: 2
# zvuMOXo8vmShFZK:
#     appdata: {data: O2eZV_r08_d07, version: 1}
#     lastupdated: '2016-04-29T07:55:47'
#     lights: ['4', '5']
#     locked: true
#     name: Nightlight
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     picture: ''
#     recycle: false
#     version: 2

# %% [markdown]
# Details of a particular scene from the list:

# %%
print yaml.safe_dump(bridge.scenes['wVXtOrFmdnySqUz']())
# Out:
# appdata: {data: skbwq_r06_d06, version: 1}
# lastupdated: '2016-08-06T18:25:59'
# lights: ['14', '21', '24', '25']
# lightstates:
#   '14': {bri: 77, ct: 366, 'on': true}
#   '21': {bri: 77, ct: 366, 'on': true}
#   '24': {bri: 77, ct: 366, 'on': true}
#   '25': {bri: 77, ct: 366, 'on': true}
# locked: false
# name: Dimmed
# owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
# picture: ''
# recycle: false
# version: 2

# %% [markdown]
# Let's list scenes with IDs, last updated time, and the lights affected:

# %%
for sid, info in scenes.items():
    print "\n{:16} {:20} {}".format( sid, info['name'], info['lastupdated'])
    for li in info['lights']:
        print "{:40}- {}".format('', lights[li]['name'])
# Out:
# 6VRh7MuKX1Nheu3  Concentrate          2016-07-23T10:43:38
#                                         - Landing
#                                         - Top Landing
#
# AsptFt3pCldMO21  Last on state        2016-07-23T10:43:34
#                                         - Front hall 1
#                                         - Front hall 2
#
# T6UzpfPUK2kmvu7  Energize             2016-07-23T10:42:49
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# cff986e21-on-15  Spring landing o     None
#                                         - Landing
#                                         - Top Landing
#
# 06869458c-on-0   Bright hall land     None
#                                         - Landing
#                                         - Front hall 1
#                                         - Front hall 2
#
# 88ae2be2b-on-0   Spring landing o     None
#                                         - Landing
#                                         - Top Landing
#
# wG25IXpcHHTim4g  Off                  2016-08-06T18:26:02
#                                         - Sitting room 2
#                                         - Sitting room 1
#                                         - Mantlepiece R
#                                         - Mantlepiece L
#
# FZxR8JD7npo7yvJ  Dimmed               2016-04-29T09:01:20
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# YDfVlYFWoaL6yv5  Nightlight           2016-08-06T18:25:59
#                                         - Sitting room 2
#                                         - Sitting room 1
#                                         - Mantlepiece R
#                                         - Mantlepiece L
#
# 597ab7b48-on-0   Warm kitchen on      None
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# N27vS4xRFx41Vxm  Nightlight           2016-04-29T09:01:21
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# zvuMOXo8vmShFZK  Nightlight           2016-04-29T07:55:47
#                                         - Landing
#                                         - Top Landing
#
# cd06c70f7-on-0   Warm sitting roo     None
#                                         - Sitting room 2
#
# 73736188f-on-0   Bright kitchen o     None
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# I6Gwi3XEvtVveHO  Bright               2016-07-23T10:31:49
#                                         - Shed
#
# efcdee1f3-on-15  Spring landing o     None
#                                         - Landing
#                                         - Top Landing
#
# -1iru0uZghuPUgV  Concentrate          2016-07-23T10:42:48
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# wVXtOrFmdnySqUz  Dimmed               2016-08-06T18:25:59
#                                         - Sitting room 2
#                                         - Sitting room 1
#                                         - Mantlepiece R
#                                         - Mantlepiece L
#
# Bwi-oM7y8oRtKBY  Relax                2016-07-23T10:43:37
#                                         - Landing
#                                         - Top Landing
#
# 1fbeb00c8-on-0   Landing low glow     None
#                                         - Landing
#
# g7tDrSN6Hpofhfj  Low glow             2016-04-29T09:01:22
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# jvY8sFPTjjgEUWo  Dimmed               2016-07-23T10:31:49
#                                         - Shed
#
# AxbidVtIKaLcaP9  Warm                 2016-04-29T08:43:51
#                                         - Front hall 1
#                                         - Front hall 2
#
# 2ed6203cf-on-0   Warm hall on 0       None
#                                         - Front hall 1
#                                         - Front hall 2
#
# 8ZOkB2fE0pxfCFl  Relax                2016-07-23T10:43:35
#                                         - Front hall 1
#                                         - Front hall 2
#
# a178eb5a3-on-0   Warm hall on 0       None
#                                         - Front hall 1
#                                         - Front hall 2
#
# jK3AIIkFATelYSp  Bright               2016-04-29T08:47:17
#                                         - Landing
#                                         - Top Landing
#
# mSrWSm46uuU0yZg  Cozy dining          2016-05-10T19:32:17
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# YS2bpqTvC-9x7vI  Cozy white           2016-05-10T19:33:34
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# d85f96e2f-on-0   Warm landing on      None
#                                         - Landing
#
# 4fa96f167-on-0   Afternoon sittin     None
#                                         - Sitting room 2
#
# 54098dd13-on-0   Laila on 0           None
#                                         - Sitting room 2
#
# 9fb67981f-on-0   Bright hall on 0     None
#                                         - Front hall 1
#                                         - Front hall 2
#
# 71616ef01-on-0   Bright hall on 0     None
#                                         - Front hall 1
#                                         - Front hall 2
#
# uTiCStN5kNYX9KM  Low glow             2016-04-29T08:46:12
#                                         - Front hall 1
#                                         - Front hall 2
#
# 199              automatic            None
#                                         - Front hall 1
#                                         - Front hall 2
#
# y8S9t3NMudgmOai  Read                 2016-07-23T10:55:58
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# 204f5998d-on-15  Spring landing o     None
#                                         - Landing
#                                         - Top Landing
#
# Af7YZIGnPJCMNkL  Energize             2016-07-23T10:43:37
#                                         - Front hall 1
#                                         - Front hall 2
#
# z7c8bEBWcHBYGA2  Off                  2016-04-29T08:51:26
#                                         - Landing
#                                         - Top Landing
#
# JtK7kjbIM6FQbpi  Evening              2016-05-02T20:35:58
#                                         - Bedroom 1
#
# r385fUT49aGqrQK  Off                  2016-04-29T09:26:43
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# SePln7Lt9-H7Hm7  Bright               2016-08-07T09:35:44
#                                         - Sitting room 2
#                                         - Sitting room 1
#                                         - Mantlepiece R
#                                         - Mantlepiece L
#
# 36bc44da7-on-0   Warm landing on      None
#                                         - Landing
#
# 12490b126-on-0   Warm hall on 0       None
#                                         - Front hall 1
#                                         - Front hall 2
#
# RrwQruSI7ErLfTy  Bright               2016-05-02T20:29:46
#                                         - Bedroom 1
#
# 1f81613a2-on-0   Spring landing o     None
#                                         - Landing
#
# b19033822-on-0   Landing low glow     None
#                                         - Landing
#                                         - Top Landing
#
# a9e5a4ab6-on-0   Winter kitchen o     2016-01-05T18:54:29
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#
# 8803a55c4-on-0   Dining on 0          None
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Front hall 1
#                                         - Front hall 2
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#
# 88ae2be2b-on-15  Spring landing o     None
#                                         - Landing
#                                         - Top Landing
#
# e21m6w2kNoxYdXQ  Concentrate          2016-05-02T20:29:45
#                                         - Bedroom 1
#
# cff986e21-on-0   Spring landing o     None
#                                         - Landing
#                                         - Top Landing
#
# v4rVpTBw3Jj2Msq  Off                  2016-04-29T08:52:37
#                                         - Landing
#                                         - Top Landing
#
# 351acdcd6-on-0   Hall low glow on     None
#                                         - Front hall 1
#                                         - Front hall 2
#
# 983ab6c2c-on-3   Low glow on 3        None
#                                         - Kitchen Sink
#                                         - Landing
#                                         - Top Landing
#                                         - Kitchen Stove
#                                         - Front hall 1
#                                         - Front hall 2
#
# 6N9am9oJ6hFdf2n  Bright               2016-07-23T11:48:50
#                                         - Landing
#                                         - Top Landing
#
# gZ5lkJ6N8lxPcQ8  Read                 2016-07-23T10:43:38
#                                         - Landing
#                                         - Top Landing
#
# bd6b33115-on-0   Bright sitting r     None
#                                         - Sitting room 2
#
# efcaf527a-on-0   Warm hall landin     None
#                                         - Landing
#                                         - Front hall 1
#                                         - Front hall 2
#
# xNSvFQPy3S-8G4I  Read                 2016-07-23T10:43:36
#                                         - Front hall 1
#                                         - Front hall 2
#
# ac7654efb-off-1  14 lights off        2016-04-13T23:59:00
#                                         - Kitchen Sink
#                                         - Landing
#                                         - Top Landing
#                                         - Kitchen Stove
#                                         - Front hall 1
#                                         - Front hall 2
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Sitting room 2
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# SUThT3XiV7sSzml  Warm                 2016-08-07T10:19:18
#                                         - Sitting room 2
#                                         - Sitting room 1
#                                         - Mantlepiece R
#                                         - Mantlepiece L
#
# d593b938b-on-0   Landing low glow     None
#                                         - Landing
#                                         - Top Landing
#
# 5kRjH0acnrfATBO  Relax                2016-07-23T10:42:45
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# b17e9e626-on-0   Beach on 0           None
#                                         - Kitchen Sink
#
# 81f2efa93-on-0   Warm sitting roo     None
#                                         - Sitting room 2
#
# dc93a70b8-off-0  10 lights off        None
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# 4a824b584-on-0   Kitchen low glow     2016-01-05T18:53:18
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# KZNM2DZmdcydRIc  All warm             2016-08-06T23:50:55
#                                         - Sitting room 2
#                                         - Sitting room 1
#                                         - Mantlepiece R
#                                         - Mantlepiece L
#
# eIgizpH1k6lP3TN  Bright               2016-04-29T09:01:23
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# 77470a3f5-off-0  2 lights off         None
#                                         - Front hall 1
#                                         - Front hall 2
#
# 7264de849-on-0   Hall low glow on     None
#                                         - Front hall 1
#                                         - Front hall 2
#
# a38572fca-on-0   Bright kitchen o     None
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# VaknVPkUZnSrdiB  Bright               2016-08-06T18:39:00
#                                         - Sitting room 2
#                                         - Sitting room 1
#                                         - Mantlepiece R
#                                         - Mantlepiece L
#
# RdOEaZplFDGXVZB  Off                  2016-04-29T08:54:08
#                                         - Landing
#                                         - Top Landing
#
# f6af64acc-off-0  4 lights off         None
#                                         - Front hall 1
#                                         - Front hall 2
#
# KFtoQ3-VRkdgALV  Warm                 2016-04-29T08:48:16
#                                         - Landing
#                                         - Top Landing
#
# XM3CA6IR2l0YiHv  Relax                2016-05-02T20:29:45
#                                         - Bedroom 1
#
# A9gvqmtnq8IIsYl  Morning              2016-05-02T20:36:28
#                                         - Bedroom 1
#
# ee511YI2hWHJ5L3  Nightlight           2016-05-02T20:29:46
#                                         - Bedroom 1
#
# fW9vVvd9InLN2ND  Dimmed               2016-05-02T20:29:46
#                                         - Bedroom 1
#
# 9812cefa8-on-0   Warm kitchen on      None
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#
# PvF0e3fVxnOekkk  Read                 2016-05-02T20:29:45
#                                         - Bedroom 1
#
# 88ae2be2b-on-30  Spring landing o     None
#                                         - Landing
#                                         - Top Landing
#
# qusSD82UJv6OIE6  Low glow             2016-04-29T08:48:43
#                                         - Landing
#                                         - Top Landing
#
# d3a196d65-on-0   Warm kitchen on      None
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# cxi4y-uCBKoV-Yd  Relax                2016-07-23T10:55:57
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# 204f5998d-on-0   Spring landing o     None
#                                         - Landing
#                                         - Top Landing
#
# befd0fc82-on-0   Winter kitchen o     None
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#
# CEt-2DBYBs2YmHV  Last on state        2016-07-23T10:42:44
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# 80236015d-on-0   Cozy dinner on 0     None
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#
# 738e3c2af-off-0  2 lights off         None
#                                         - Landing
#                                         - Top Landing
#
# 80bfa951a-on-0   Cozy dinner on 0     None
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# eb0d9d166-off-0  7 lights off         None
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# 342dc4014-on-0   Landing low glow     None
#                                         - Landing
#                                         - Top Landing
#
# 1204e3dd0-on-0   Warm kitchen on      None
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# 357d74e5d-on-0   Cozy dinner on 0     2016-01-05T18:54:46
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# 3jOcNGuX09DIzrl  Concentrate          2016-07-23T10:43:36
#                                         - Front hall 1
#                                         - Front hall 2
#
# 2HASTwKUVsTGD7l  Off                  2016-07-23T11:48:50
#                                         - Landing
#                                         - Top Landing
#
# 1c0d0ffc2-on-0   Venice night on      2016-01-05T18:54:10
#                                         - Kitchen Sink
#
# a4fe6838e-on-0   Spring landing o     None
#                                         - Landing
#
# IB57U3scrj4cQWk  Read                 2016-08-06T18:25:58
#                                         - Sitting room 2
#                                         - Sitting room 1
#                                         - Mantlepiece R
#                                         - Mantlepiece L
#
# 67f767f32-on-0   Automatic on 0       None
#                                         - Front hall 1
#                                         - Front hall 2
#
# 50e86426a-on-0   Kitchen low glow     None
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# Wny1y4JoTVmZJo3  Energize             2016-07-23T10:56:01
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# AR-I2sRzlFCgcC5  Energize             2016-05-02T20:29:45
#                                         - Bedroom 1
#
# 3owQUn01W7nVsxR  Evening              2016-08-07T10:19:47
#                                         - Sitting room 2
#                                         - Sitting room 1
#                                         - Mantlepiece R
#                                         - Mantlepiece L
#
# Rb2sR3LlDBaBlo2  Concentrate          2016-07-23T10:56:00
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# QnxaMuiruvrYmvI  Energize             2016-07-23T10:43:38
#                                         - Landing
#                                         - Top Landing
#
# 07981a34a-on-0   Warm landing on      None
#                                         - Landing
#                                         - Top Landing
#
# ff2dd0ec0-on-0   Afternoon Sittin     None
#                                         - Sitting room 2
#
# c1dcf5510-on-0   Warm hall landin     None
#                                         - Landing
#                                         - Front hall 1
#                                         - Front hall 2
#
# pIClVVDfAj2awSK  Read                 2016-07-23T10:42:46
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# 0f7797c16-on-0   Dining on 0          None
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Front hall 1
#                                         - Front hall 2
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# qnLLDH8uKdhkKXR  Last on state        2016-07-23T10:55:56
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# JFb70MR1pTrdTd1  Dimmed               2016-04-29T07:55:47
#                                         - Landing
#                                         - Top Landing
#
# in-NXNYKlDikoMa  Spring blossom       2016-04-29T07:55:48
#                                         - Landing
#                                         - Top Landing
#
# ON-DIMMER        Dimmer scene         None
#                                         - Kitchen Sink
#                                         - Landing
#                                         - Top Landing
#                                         - Kitchen Stove
#                                         - Front hall 1
#                                         - Front hall 2
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Sitting room 2
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# o3EjXJ2eZJVt-Yp  Bright               2016-04-29T08:44:50
#                                         - Front hall 1
#                                         - Front hall 2
#
# 16c1f1a5b-on-0   Spring landing o     None
#                                         - Landing
#                                         - Top Landing
#
# fd2a7188f-on-0   Dining on 0          2016-01-05T18:54:53
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Front hall 1
#                                         - Front hall 2
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# be67e9401-off-2  10 lights off        None
#                                         - Kitchen Sink
#                                         - Landing
#                                         - Top Landing
#                                         - Kitchen Stove
#                                         - Front hall 1
#                                         - Front hall 2
#
# 47afc46c7-off-0  2 lights off         None
#                                         - Sitting room 2
#
# a49b85109-on-0   Bright hall land     None
#                                         - Landing
#                                         - Front hall 1
#                                         - Front hall 2
#
# 0d9qlRyOk7Td5-0  Dimmed               2016-04-29T07:54:46
#                                         - Front hall 1
#                                         - Front hall 2
#
# vljsBHKjn0LCnfB  Nightlight           2016-04-29T07:54:46
#                                         - Front hall 1
#                                         - Front hall 2
#
# efcdee1f3-on-0   Spring landing o     None
#                                         - Landing
#                                         - Top Landing
#
# EZJc3EGonto7WIN  Nightlight           2016-07-23T10:31:49
#                                         - Shed
#
# WOZVY1DKAc6MjKx  Warm                 2016-04-29T09:01:22
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# ef2edea8e-on-0   Kitchen low glow     None
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#
# 466675cc0-on-0   Kitchen low glow     2016-01-05T18:51:32
#                                         - Kitchen Sink
#                                         - Kitchen Stove
#                                         - Kitchen table
#                                         - Kitchen
#                                         - Picture rail
#                                         - Dining table 3
#                                         - Dining table 1
#                                         - Dining table 2
#
# zifBdqd-uYwto1C  Last on state        2016-07-23T10:43:37
#                                         - Landing
#                                         - Top Landing

# %% [markdown]
# Tidying things up; let's delete a scene:

# %%
# Uncomment and edit this if you actually want to run it!
# print bridge.scenes['cd06c70f7-on-0'](http_method='delete')
# Out:
# [{u'success': u'/scenes/cd06c70f7-on-0 deleted'}]

# %% [markdown]
# Show the details of the scenes that affect a particular light:

# %%
lightname = 'Sitting room 1'
# How's this for a nice use of python iterators?
light_id = next(i for i,info in lights.items() if info['name'] == lightname)
print "Light", light_id, lightname
for line in ["{} : {:20} {}".format(sid, info['name'], info['lastupdated']) for sid, info in scenes.items() if light_id in info['lights']]:
    print line
# Out:
# Light 21 Sitting room 1
# wG25IXpcHHTim4g : Off                  2016-08-06T18:26:02
# YDfVlYFWoaL6yv5 : Nightlight           2016-08-06T18:25:59
# wVXtOrFmdnySqUz : Dimmed               2016-08-06T18:25:59
# SePln7Lt9-H7Hm7 : Bright               2016-08-07T09:35:44
# SUThT3XiV7sSzml : Warm                 2016-08-07T10:19:18
# KZNM2DZmdcydRIc : All warm             2016-08-06T23:50:55
# VaknVPkUZnSrdiB : Bright               2016-08-06T18:39:00
# IB57U3scrj4cQWk : Read                 2016-08-06T18:25:58
# 3owQUn01W7nVsxR : Evening              2016-08-07T10:19:47

# %% [markdown]
# ## Groups and rooms

# %% [markdown]
# Let's look at groups:

# %%
print yaml.safe_dump(bridge.groups(), indent=4)
# Out:
# '1':
#     action:
#         alert: none
#         bri: 254
#         colormode: xy
#         ct: 262
#         effect: none
#         hue: 16635
#         'on': true
#         sat: 18
#         xy: [0.389, 0.3819]
#     lights: ['3', '6']
#     name: Kitchen
#     recycle: false
#     state: {all_on: true, any_on: true}
#     type: LightGroup
# '2':
#     action:
#         alert: none
#         bri: 144
#         colormode: xy
#         ct: 443
#         effect: none
#         hue: 13524
#         'on': false
#         sat: 200
#         xy: [0.5017, 0.4152]
#     lights: ['7', '8']
#     name: Hall
#     recycle: false
#     state: {all_on: false, any_on: false}
#     type: LightGroup
# '3':
#     action:
#         alert: none
#         bri: 254
#         colormode: xy
#         ct: 226
#         effect: none
#         hue: 33887
#         'on': true
#         sat: 61
#         xy: [0.3649, 0.3665]
#     lights: ['12', '11', '6', '3']
#     name: Dimmer 11
#     recycle: false
#     state: {all_on: true, any_on: true}
#     type: LightGroup
# '4':
#     action:
#         alert: none
#         bri: 254
#         colormode: xy
#         ct: 153
#         effect: none
#         hue: 41136
#         'on': true
#         sat: 80
#         xy: [0.3103, 0.3301]
#     class: Kitchen
#     lights: ['3', '6', '11', '12', '16', '17', '18', '15']
#     name: Kitchen
#     state: {all_on: true, any_on: true}
#     type: Room
# '5':
#     action: {alert: none, bri: 254, 'on': false}
#     class: Garden
#     lights: ['23']
#     name: Garden
#     state: {all_on: false, any_on: false}
#     type: Room
# '6':
#     action:
#         alert: select
#         bri: 254
#         colormode: ct
#         ct: 185
#         effect: none
#         hue: 13401
#         'on': true
#         sat: 252
#         xy: [0.5345, 0.4242]
#     class: Living room
#     lights: ['14', '21', '24', '25']
#     name: Sitting room
#     state: {all_on: true, any_on: true}
#     type: Room
# '7':
#     action:
#         alert: none
#         bri: 144
#         colormode: xy
#         ct: 443
#         effect: none
#         hue: 13524
#         'on': false
#         sat: 200
#         xy: [0.5017, 0.4152]
#     class: Hallway
#     lights: ['7', '8']
#     name: Hall
#     state: {all_on: false, any_on: false}
#     type: Room
# '8':
#     action:
#         alert: none
#         bri: 52
#         colormode: xy
#         ct: 500
#         effect: none
#         hue: 6369
#         'on': false
#         sat: 252
#         xy: [0.607, 0.3708]
#     class: Hallway
#     lights: ['4', '5']
#     name: Landing
#     state: {all_on: false, any_on: false}
#     type: Room
# '9':
#     action: {alert: none, bri: 254, colormode: ct, ct: 366, 'on': true}
#     class: Bedroom
#     lights: ['22']
#     name: Bedroom
#     state: {all_on: true, any_on: true}
#     type: Room

# %% [markdown]
# The current Hue software creates 'rooms', which are groups with a type value set to Room:

# %%
groups = bridge.groups()
rooms = [(gid, info['name']) for gid, info in groups.items() if info.get('type') == 'Room' ]
for room_id, info in rooms:
    print "{:3} : {}".format(room_id, info)
# Out:
# 5   : Garden
# 4   : Kitchen
# 7   : Hall
# 6   : Sitting room
# 9   : Bedroom
# 8   : Landing

# %% [markdown]
# ## Sensors

# %% [markdown]
# Sensors are mostly switches, but a few other things come under the same category in the bridge.  There's a 'daylight' sensor, implemented in software, for example, and various bits of state can also be stored here so they can be used in rule conditions later.

# %%
sensors = bridge.sensors()
summary = [(info['name'], i, info['type']) for i,info in sensors.items()]
summary.sort(lambda a,b: cmp(a[0], b[0]))  # Sort by name
for n,i,t in summary:
    print "{:30} {:>3} {}".format(n,i,t) 
    #print bridge.sensors[i]()
# Out:
# Bedroom tap                      7 ZGPSwitch
# Daylight                         1 Daylight
# Dimmer Switch 11 SceneCycle     14 CLIPGenericStatus
# Dimmer Switch 12 SceneCycle     13 CLIPGenericStatus
# Dining Room                      9 ZGPSwitch
# Hall                             8 ZGPSwitch
# Hall dimmer                     12 ZLLSwitch
# Kitchen dimmer                  11 ZLLSwitch
# Kitchen tap                      2 ZGPSwitch
# Landing tap                      3 ZGPSwitch
# Laundry tap                      4 ZGPSwitch
# Sitting room                    10 ZGPSwitch
# Top Tap                          6 ZGPSwitch

# %% [markdown]
# Here's a more complete list:

# %%
print yaml.safe_dump(bridge.sensors(), indent=4)
# Out:
# '1':
#     config: {lat: none, long: none, 'on': true, sunriseoffset: 30, sunsetoffset: -30}
#     manufacturername: Philips
#     modelid: PHDL00
#     name: Daylight
#     state: {daylight: null, lastupdated: none}
#     swversion: '1.0'
#     type: Daylight
# '10':
#     config: {'on': true}
#     manufacturername: Philips
#     modelid: ZGPSWITCH
#     name: Sitting room
#     state: {buttonevent: 34, lastupdated: '2016-08-07T10:20:04'}
#     type: ZGPSwitch
#     uniqueid: 00:00:00:00:00:41:1f:34-f2
# '11':
#     config: {battery: 100, 'on': true, reachable: true}
#     manufacturername: Philips
#     modelid: RWL021
#     name: Kitchen dimmer
#     state: {buttonevent: null, lastupdated: none}
#     swversion: 5.45.1.17846
#     type: ZLLSwitch
#     uniqueid: 00:17:88:01:10:33:28:66-02-fc00
# '12':
#     config: {battery: 100, 'on': true, reachable: true}
#     manufacturername: Philips
#     modelid: RWL021
#     name: Hall dimmer
#     state: {buttonevent: 1002, lastupdated: '2016-08-06T22:50:32'}
#     swversion: 5.45.1.17846
#     type: ZLLSwitch
#     uniqueid: 00:17:88:01:10:39:f3:0e-02-fc00
# '13':
#     config: {'on': true, reachable: true}
#     manufacturername: Philips
#     modelid: PHWA01
#     name: Dimmer Switch 12 SceneCycle
#     recycle: true
#     state: {lastupdated: '2016-08-06T22:50:42', status: 0}
#     swversion: '1.0'
#     type: CLIPGenericStatus
#     uniqueid: WA0001
# '14':
#     config: {'on': true, reachable: true}
#     manufacturername: Philips
#     modelid: PHWA01
#     name: Dimmer Switch 11 SceneCycle
#     recycle: true
#     state: {lastupdated: none, status: 0}
#     swversion: '1.0'
#     type: CLIPGenericStatus
#     uniqueid: WA0001
# '2':
#     config: {'on': true}
#     manufacturername: Philips
#     modelid: ZGPSWITCH
#     name: Kitchen tap
#     state: {buttonevent: 34, lastupdated: '2016-08-07T09:15:17'}
#     type: ZGPSwitch
#     uniqueid: 00:00:00:00:00:40:46:c4-f2
# '3':
#     config: {'on': true}
#     manufacturername: Philips
#     modelid: ZGPSWITCH
#     name: Landing tap
#     state: {buttonevent: 34, lastupdated: '2016-08-07T00:13:21'}
#     type: ZGPSwitch
#     uniqueid: 00:00:00:00:00:40:51:f4-f2
# '4':
#     config: {'on': true}
#     manufacturername: Philips
#     modelid: ZGPSWITCH
#     name: Laundry tap
#     state: {buttonevent: null, lastupdated: none}
#     type: ZGPSwitch
#     uniqueid: 00:00:00:00:00:40:81:93-f2
# '6':
#     config: {'on': true}
#     manufacturername: Philips
#     modelid: ZGPSWITCH
#     name: Top Tap
#     state: {buttonevent: 17, lastupdated: '2016-08-05T20:03:20'}
#     type: ZGPSwitch
#     uniqueid: 00:00:00:00:00:40:86:2b-f2
# '7':
#     config: {'on': true}
#     manufacturername: Philips
#     modelid: ZGPSWITCH
#     name: Bedroom tap
#     state: {buttonevent: 18, lastupdated: '2016-08-06T23:56:16'}
#     type: ZGPSwitch
#     uniqueid: 00:00:00:00:00:40:5f:88-f2
# '8':
#     config: {'on': true}
#     manufacturername: Philips
#     modelid: ZGPSWITCH
#     name: Hall
#     state: {buttonevent: 34, lastupdated: '2016-08-06T20:50:22'}
#     type: ZGPSwitch
#     uniqueid: 00:00:00:00:00:42:79:ca-f2
# '9':
#     config: {'on': true}
#     manufacturername: Philips
#     modelid: ZGPSWITCH
#     name: Dining Room
#     state: {buttonevent: 17, lastupdated: '2016-08-06T23:59:23'}
#     type: ZGPSwitch
#     uniqueid: 00:00:00:00:00:40:8d:d5-f2

# %% [markdown]
# ## Rules
#
# Rules map sensor events etc. to actions.

# %%
rules = bridge.rules()
print yaml.safe_dump(rules, indent=4)
# Out:
# '1':
#     actions:
#     -   address: /groups/4/action
#         body: {scene: g7tDrSN6Hpofhfj}
#         method: PUT
#     conditions:
#     - {address: /sensors/2/state/lastupdated, operator: dx}
#     - {address: /sensors/2/state/buttonevent, operator: eq, value: '18'}
#     created: '2016-04-29T08:22:45'
#     lasttriggered: '2016-08-06T20:49:59'
#     name: Tap 2.4
#     owner: s4zx5V9P01QX2tXIQpntlzfzVHfLpBLscIGWgfqP
#     recycle: false
#     status: enabled
#     timestriggered: 2
# '10':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: zvuMOXo8vmShFZK}
#         method: PUT
#     conditions:
#     - {address: /sensors/4/state/lastupdated, operator: dx}
#     - {address: /sensors/4/state/buttonevent, operator: eq, value: '18'}
#     created: '2016-07-23T11:48:50'
#     lasttriggered: none
#     name: Tap 4.4
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 0
# '11':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: 2HASTwKUVsTGD7l}
#         method: PUT
#     conditions:
#     - {address: /sensors/4/state/lastupdated, operator: dx}
#     - {address: /sensors/4/state/buttonevent, operator: eq, value: '34'}
#     created: '2016-07-23T11:48:51'
#     lasttriggered: none
#     name: Tap 4.1
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 0
# '12':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: 6N9am9oJ6hFdf2n}
#         method: PUT
#     conditions:
#     - {address: /sensors/4/state/lastupdated, operator: dx}
#     - {address: /sensors/4/state/buttonevent, operator: eq, value: '16'}
#     created: '2016-07-23T11:48:51'
#     lasttriggered: none
#     name: Tap 4.2
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 0
# '13':
#     actions:
#     -   address: /groups/0/action
#         body: {scene: efcaf527a-on-0}
#         method: PUT
#     conditions:
#     - {address: /sensors/8/state/buttonevent, operator: eq, value: '17'}
#     - {address: /sensors/8/state/lastupdated, operator: dx}
#     created: '2015-04-19T22:49:05'
#     lasttriggered: '2016-08-06T20:50:19'
#     name: Tap 8.3 Warm hall landing
#     owner: jPxnh5fWE3levI28
#     recycle: false
#     status: enabled
#     timestriggered: 1
# '14':
#     actions:
#     -   address: /groups/0/action
#         body: {scene: a49b85109-on-0}
#         method: PUT
#     conditions:
#     - {address: /sensors/8/state/buttonevent, operator: eq, value: '16'}
#     - {address: /sensors/8/state/lastupdated, operator: dx}
#     created: '2015-04-19T22:50:12'
#     lasttriggered: none
#     name: Tap 8.2 Bright hall landing
#     owner: jPxnh5fWE3levI28
#     recycle: false
#     status: enabled
#     timestriggered: 0
# '15':
#     actions:
#     -   address: /groups/0/action
#         body: {scene: d3a196d65-on-0}
#         method: PUT
#     conditions:
#     - {address: /sensors/9/state/buttonevent, operator: eq, value: '17'}
#     - {address: /sensors/9/state/lastupdated, operator: dx}
#     created: '2015-11-08T20:04:38'
#     lasttriggered: '2016-08-06T23:59:23'
#     name: Tap 9.3 Warm kitchen
#     owner: eYXkeVdweVI6FZIW
#     recycle: false
#     status: enabled
#     timestriggered: 3
# '16':
#     actions:
#     -   address: /groups/0/action
#         body: {scene: dc93a70b8-off-0}
#         method: PUT
#     conditions:
#     - {address: /sensors/9/state/buttonevent, operator: eq, value: '34'}
#     - {address: /sensors/9/state/lastupdated, operator: dx}
#     created: '2015-11-07T17:58:29'
#     lasttriggered: '2016-08-05T22:41:14'
#     name: Tap 9.1 10 lights off
#     owner: eYXkeVdweVI6FZIW
#     recycle: false
#     status: enabled
#     timestriggered: 2
# '17':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: KFtoQ3-VRkdgALV}
#         method: PUT
#     conditions:
#     - {address: /sensors/6/state/lastupdated, operator: dx}
#     - {address: /sensors/6/state/buttonevent, operator: eq, value: '17'}
#     created: '2016-04-29T08:52:36'
#     lasttriggered: '2016-08-05T20:03:20'
#     name: Tap 6.3
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 1
# '18':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: jK3AIIkFATelYSp}
#         method: PUT
#     conditions:
#     - {address: /sensors/6/state/lastupdated, operator: dx}
#     - {address: /sensors/6/state/buttonevent, operator: eq, value: '16'}
#     created: '2016-04-29T08:52:37'
#     lasttriggered: none
#     name: Tap 6.2
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 0
# '19':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: qusSD82UJv6OIE6}
#         method: PUT
#     conditions:
#     - {address: /sensors/6/state/lastupdated, operator: dx}
#     - {address: /sensors/6/state/buttonevent, operator: eq, value: '18'}
#     created: '2016-04-29T08:52:37'
#     lasttriggered: none
#     name: Tap 6.4
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 0
# '2':
#     actions:
#     -   address: /groups/4/action
#         body: {scene: eIgizpH1k6lP3TN}
#         method: PUT
#     conditions:
#     - {address: /sensors/2/state/lastupdated, operator: dx}
#     - {address: /sensors/2/state/buttonevent, operator: eq, value: '16'}
#     created: '2016-04-29T09:26:43'
#     lasttriggered: '2016-08-07T07:24:29'
#     name: Tap 2.2
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 1
# '20':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: v4rVpTBw3Jj2Msq}
#         method: PUT
#     conditions:
#     - {address: /sensors/6/state/lastupdated, operator: dx}
#     - {address: /sensors/6/state/buttonevent, operator: eq, value: '34'}
#     created: '2016-04-29T08:52:37'
#     lasttriggered: none
#     name: Tap 6.1
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 0
# '21':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: KFtoQ3-VRkdgALV}
#         method: PUT
#     conditions:
#     - {address: /sensors/7/state/lastupdated, operator: dx}
#     - {address: /sensors/7/state/buttonevent, operator: eq, value: '17'}
#     created: '2016-04-29T08:54:05'
#     lasttriggered: '2016-08-05T22:39:39'
#     name: Tap 7.3
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 1
# '22':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: jK3AIIkFATelYSp}
#         method: PUT
#     conditions:
#     - {address: /sensors/7/state/lastupdated, operator: dx}
#     - {address: /sensors/7/state/buttonevent, operator: eq, value: '16'}
#     created: '2016-04-29T08:54:06'
#     lasttriggered: none
#     name: Tap 7.2
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 0
# '23':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: qusSD82UJv6OIE6}
#         method: PUT
#     conditions:
#     - {address: /sensors/7/state/lastupdated, operator: dx}
#     - {address: /sensors/7/state/buttonevent, operator: eq, value: '18'}
#     created: '2016-04-29T08:54:06'
#     lasttriggered: '2016-08-06T23:56:16'
#     name: Tap 7.4
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 4
# '24':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: RdOEaZplFDGXVZB}
#         method: PUT
#     conditions:
#     - {address: /sensors/7/state/lastupdated, operator: dx}
#     - {address: /sensors/7/state/buttonevent, operator: eq, value: '34'}
#     created: '2016-04-29T08:54:08'
#     lasttriggered: '2016-08-05T22:41:58'
#     name: Tap 7.1
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 2
# '25':
#     actions:
#     -   address: /groups/0/action
#         body: {scene: 50e86426a-on-0}
#         method: PUT
#     conditions:
#     - {address: /sensors/9/state/buttonevent, operator: eq, value: '18'}
#     - {address: /sensors/9/state/lastupdated, operator: dx}
#     created: '2015-11-07T18:03:39'
#     lasttriggered: none
#     name: Tap 9.4 Kitchen low glow
#     owner: eYXkeVdweVI6FZIW
#     recycle: false
#     status: enabled
#     timestriggered: 0
# '26':
#     actions:
#     -   address: /groups/0/action
#         body: {scene: f6af64acc-off-0}
#         method: PUT
#     conditions:
#     - {address: /sensors/8/state/buttonevent, operator: eq, value: '34'}
#     - {address: /sensors/8/state/lastupdated, operator: dx}
#     created: '2014-10-14T19:35:02'
#     lasttriggered: '2016-08-06T20:50:22'
#     name: Tap 8.1 4 lights off
#     owner: jPxnh5fWE3levI28
#     recycle: false
#     status: enabled
#     timestriggered: 2
# '27':
#     actions:
#     -   address: /groups/0/action
#         body: {scene: 351acdcd6-on-0}
#         method: PUT
#     conditions:
#     - {address: /sensors/8/state/buttonevent, operator: eq, value: '18'}
#     - {address: /sensors/8/state/lastupdated, operator: dx}
#     created: '2014-11-16T20:42:03'
#     lasttriggered: none
#     name: Tap 8.4 Hall low glow
#     owner: jPxnh5fWE3levI28
#     recycle: false
#     status: enabled
#     timestriggered: 0
# '28':
#     actions:
#     -   address: /groups/0/action
#         body: {scene: a38572fca-on-0}
#         method: PUT
#     conditions:
#     - {address: /sensors/9/state/buttonevent, operator: eq, value: '16'}
#     - {address: /sensors/9/state/lastupdated, operator: dx}
#     created: '2015-11-07T18:03:39'
#     lasttriggered: '2016-08-06T18:17:58'
#     name: Tap 9.2 Bright kitchen
#     owner: eYXkeVdweVI6FZIW
#     recycle: false
#     status: enabled
#     timestriggered: 2
# '29':
#     actions:
#     -   address: /groups/6/action
#         body: {scene: SUThT3XiV7sSzml}
#         method: PUT
#     conditions:
#     - {address: /sensors/10/state/lastupdated, operator: dx}
#     - {address: /sensors/10/state/buttonevent, operator: eq, value: '17'}
#     created: '2016-04-29T08:38:50'
#     lasttriggered: '2016-08-07T10:20:01'
#     name: Tap 10.3
#     owner: s4zx5V9P01QX2tXIQpntlzfzVHfLpBLscIGWgfqP
#     recycle: false
#     status: enabled
#     timestriggered: 27
# '3':
#     actions:
#     -   address: /groups/4/action
#         body: {scene: WOZVY1DKAc6MjKx}
#         method: PUT
#     conditions:
#     - {address: /sensors/2/state/lastupdated, operator: dx}
#     - {address: /sensors/2/state/buttonevent, operator: eq, value: '17'}
#     created: '2016-04-29T15:56:53'
#     lasttriggered: '2016-08-07T07:22:52'
#     name: Tap 2.3
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 4
# '30':
#     actions:
#     -   address: /groups/6/action
#         body: {scene: SePln7Lt9-H7Hm7}
#         method: PUT
#     conditions:
#     - {address: /sensors/10/state/lastupdated, operator: dx}
#     - {address: /sensors/10/state/buttonevent, operator: eq, value: '16'}
#     created: '2016-04-29T08:33:51'
#     lasttriggered: '2016-08-07T10:19:59'
#     name: Tap 10.2
#     owner: s4zx5V9P01QX2tXIQpntlzfzVHfLpBLscIGWgfqP
#     recycle: false
#     status: enabled
#     timestriggered: 27
# '31':
#     actions:
#     -   address: /groups/6/action
#         body: {scene: 3owQUn01W7nVsxR}
#         method: PUT
#     conditions:
#     - {address: /sensors/10/state/lastupdated, operator: dx}
#     - {address: /sensors/10/state/buttonevent, operator: eq, value: '18'}
#     created: '2016-04-29T08:33:51'
#     lasttriggered: '2016-08-07T10:20:02'
#     name: Tap 10.4
#     owner: s4zx5V9P01QX2tXIQpntlzfzVHfLpBLscIGWgfqP
#     recycle: false
#     status: enabled
#     timestriggered: 15
# '32':
#     actions:
#     -   address: /groups/6/action
#         body: {scene: wG25IXpcHHTim4g}
#         method: PUT
#     conditions:
#     - {address: /sensors/10/state/lastupdated, operator: dx}
#     - {address: /sensors/10/state/buttonevent, operator: eq, value: '34'}
#     created: '2016-04-29T08:33:51'
#     lasttriggered: '2016-08-07T10:20:04'
#     name: Tap 10.1
#     owner: s4zx5V9P01QX2tXIQpntlzfzVHfLpBLscIGWgfqP
#     recycle: false
#     status: enabled
#     timestriggered: 23
# '33':
#     actions:
#     -   address: /groups/4/action
#         body: {scene: qnLLDH8uKdhkKXR}
#         method: PUT
#     -   address: /sensors/14/state
#         body: {status: 1}
#         method: PUT
#     conditions:
#     - {address: /sensors/14/state/status, operator: lt, value: '1'}
#     - {address: /sensors/11/state/buttonevent, operator: eq, value: '1000'}
#     - {address: /sensors/11/state/lastupdated, operator: dx}
#     created: '2016-07-23T10:56:02'
#     lasttriggered: none
#     name: Dimmer Switch 11 on0
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '34':
#     actions:
#     -   address: /groups/4/action
#         body: {scene: cxi4y-uCBKoV-Yd}
#         method: PUT
#     -   address: /sensors/14/state
#         body: {status: 2}
#         method: PUT
#     conditions:
#     - {address: /sensors/14/state/status, operator: eq, value: '1'}
#     - {address: /sensors/11/state/buttonevent, operator: eq, value: '1000'}
#     - {address: /sensors/11/state/lastupdated, operator: dx}
#     created: '2016-07-23T10:56:02'
#     lasttriggered: none
#     name: Dimmer Switch 11 on1
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '35':
#     actions:
#     -   address: /groups/4/action
#         body: {scene: y8S9t3NMudgmOai}
#         method: PUT
#     -   address: /sensors/14/state
#         body: {status: 3}
#         method: PUT
#     conditions:
#     - {address: /sensors/14/state/status, operator: eq, value: '2'}
#     - {address: /sensors/11/state/buttonevent, operator: eq, value: '1000'}
#     - {address: /sensors/11/state/lastupdated, operator: dx}
#     created: '2016-07-23T10:56:02'
#     lasttriggered: none
#     name: Dimmer Switch 11 on2
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '36':
#     actions:
#     -   address: /groups/4/action
#         body: {scene: Rb2sR3LlDBaBlo2}
#         method: PUT
#     -   address: /sensors/14/state
#         body: {status: 4}
#         method: PUT
#     conditions:
#     - {address: /sensors/14/state/status, operator: eq, value: '3'}
#     - {address: /sensors/11/state/buttonevent, operator: eq, value: '1000'}
#     - {address: /sensors/11/state/lastupdated, operator: dx}
#     created: '2016-07-23T10:56:02'
#     lasttriggered: none
#     name: Dimmer Switch 11 on3
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '37':
#     actions:
#     -   address: /groups/4/action
#         body: {scene: Wny1y4JoTVmZJo3}
#         method: PUT
#     -   address: /sensors/14/state
#         body: {status: 0}
#         method: PUT
#     conditions:
#     - {address: /sensors/14/state/status, operator: gt, value: '3'}
#     - {address: /sensors/11/state/buttonevent, operator: eq, value: '1000'}
#     - {address: /sensors/11/state/lastupdated, operator: dx}
#     created: '2016-07-23T10:56:02'
#     lasttriggered: none
#     name: Dimmer Switch 11 on4
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '38':
#     actions:
#     -   address: /schedules/8
#         body: {localtime: 'PT00:00:10', status: enabled}
#         method: PUT
#     conditions:
#     - {address: /sensors/11/state/lastupdated, operator: dx}
#     created: '2016-07-23T10:56:02'
#     lasttriggered: none
#     name: Dimmer Switch 11 reset timer
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '39':
#     actions:
#     -   address: /groups/4/action
#         body: {bri_inc: -30, transitiontime: 9}
#         method: PUT
#     conditions:
#     - {address: /sensors/11/state/lastupdated, operator: dx}
#     - {address: /sensors/11/state/buttonevent, operator: eq, value: '3000'}
#     created: '2016-07-23T10:56:02'
#     lasttriggered: none
#     name: Dimmer 11.3 Lights
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '4':
#     actions:
#     -   address: /groups/4/action
#         body: {scene: r385fUT49aGqrQK}
#         method: PUT
#     conditions:
#     - {address: /sensors/2/state/lastupdated, operator: dx}
#     - {address: /sensors/2/state/buttonevent, operator: eq, value: '34'}
#     created: '2016-04-29T09:26:44'
#     lasttriggered: '2016-08-07T09:15:17'
#     name: Tap 2.1
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 5
# '40':
#     actions:
#     -   address: /groups/4/action
#         body: {bri_inc: -56, transitiontime: 9}
#         method: PUT
#     conditions:
#     - {address: /sensors/11/state/lastupdated, operator: dx}
#     - {address: /sensors/11/state/buttonevent, operator: eq, value: '3001'}
#     created: '2016-07-23T10:56:03'
#     lasttriggered: none
#     name: Dimmer 11.3 Lights
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '41':
#     actions:
#     -   address: /groups/7/action
#         body: {scene: AsptFt3pCldMO21}
#         method: PUT
#     -   address: /groups/8/action
#         body: {scene: zifBdqd-uYwto1C}
#         method: PUT
#     -   address: /sensors/13/state
#         body: {status: 1}
#         method: PUT
#     conditions:
#     - {address: /sensors/13/state/status, operator: lt, value: '1'}
#     - {address: /sensors/12/state/buttonevent, operator: eq, value: '1000'}
#     - {address: /sensors/12/state/lastupdated, operator: dx}
#     created: '2016-07-23T10:43:39'
#     lasttriggered: '2016-08-06T22:50:31'
#     name: Dimmer Switch 12 on0
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 3
# '42':
#     actions:
#     -   address: /groups/7/action
#         body: {scene: 8ZOkB2fE0pxfCFl}
#         method: PUT
#     -   address: /groups/8/action
#         body: {scene: Bwi-oM7y8oRtKBY}
#         method: PUT
#     -   address: /sensors/13/state
#         body: {status: 2}
#         method: PUT
#     conditions:
#     - {address: /sensors/13/state/status, operator: eq, value: '1'}
#     - {address: /sensors/12/state/buttonevent, operator: eq, value: '1000'}
#     - {address: /sensors/12/state/lastupdated, operator: dx}
#     created: '2016-07-23T10:43:39'
#     lasttriggered: '2016-08-06T22:50:32'
#     name: Dimmer Switch 12 on1
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 1
# '43':
#     actions:
#     -   address: /groups/7/action
#         body: {scene: xNSvFQPy3S-8G4I}
#         method: PUT
#     -   address: /groups/8/action
#         body: {scene: gZ5lkJ6N8lxPcQ8}
#         method: PUT
#     -   address: /sensors/13/state
#         body: {status: 3}
#         method: PUT
#     conditions:
#     - {address: /sensors/13/state/status, operator: eq, value: '2'}
#     - {address: /sensors/12/state/buttonevent, operator: eq, value: '1000'}
#     - {address: /sensors/12/state/lastupdated, operator: dx}
#     created: '2016-07-23T10:43:39'
#     lasttriggered: none
#     name: Dimmer Switch 12 on2
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '44':
#     actions:
#     -   address: /groups/7/action
#         body: {scene: 3jOcNGuX09DIzrl}
#         method: PUT
#     -   address: /groups/8/action
#         body: {scene: 6VRh7MuKX1Nheu3}
#         method: PUT
#     -   address: /sensors/13/state
#         body: {status: 4}
#         method: PUT
#     conditions:
#     - {address: /sensors/13/state/status, operator: eq, value: '3'}
#     - {address: /sensors/12/state/buttonevent, operator: eq, value: '1000'}
#     - {address: /sensors/12/state/lastupdated, operator: dx}
#     created: '2016-07-23T10:43:39'
#     lasttriggered: none
#     name: Dimmer Switch 12 on3
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '45':
#     actions:
#     -   address: /groups/7/action
#         body: {scene: Af7YZIGnPJCMNkL}
#         method: PUT
#     -   address: /groups/8/action
#         body: {scene: QnxaMuiruvrYmvI}
#         method: PUT
#     -   address: /sensors/13/state
#         body: {status: 0}
#         method: PUT
#     conditions:
#     - {address: /sensors/13/state/status, operator: gt, value: '3'}
#     - {address: /sensors/12/state/buttonevent, operator: eq, value: '1000'}
#     - {address: /sensors/12/state/lastupdated, operator: dx}
#     created: '2016-07-23T10:43:39'
#     lasttriggered: none
#     name: Dimmer Switch 12 on4
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '46':
#     actions:
#     -   address: /schedules/7
#         body: {localtime: 'PT00:00:10', status: enabled}
#         method: PUT
#     conditions:
#     - {address: /sensors/12/state/lastupdated, operator: dx}
#     created: '2016-07-23T10:43:39'
#     lasttriggered: '2016-08-06T22:50:32'
#     name: Dimmer Switch 12 reset timer
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 8
# '47':
#     actions:
#     -   address: /groups/7/action
#         body: {bri_inc: -30, transitiontime: 9}
#         method: PUT
#     -   address: /groups/8/action
#         body: {bri_inc: -30, transitiontime: 9}
#         method: PUT
#     conditions:
#     - {address: /sensors/12/state/lastupdated, operator: dx}
#     - {address: /sensors/12/state/buttonevent, operator: eq, value: '3000'}
#     created: '2016-07-23T10:43:40'
#     lasttriggered: none
#     name: Dimmer 12.3 Lights
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '48':
#     actions:
#     -   address: /groups/7/action
#         body: {bri_inc: -56, transitiontime: 9}
#         method: PUT
#     -   address: /groups/8/action
#         body: {bri_inc: -56, transitiontime: 9}
#         method: PUT
#     conditions:
#     - {address: /sensors/12/state/lastupdated, operator: dx}
#     - {address: /sensors/12/state/buttonevent, operator: eq, value: '3001'}
#     created: '2016-07-23T10:43:40'
#     lasttriggered: none
#     name: Dimmer 12.3 Lights
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '49':
#     actions:
#     -   address: /groups/7/action
#         body: {bri_inc: 0}
#         method: PUT
#     -   address: /groups/8/action
#         body: {bri_inc: 0}
#         method: PUT
#     conditions:
#     - {address: /sensors/12/state/lastupdated, operator: dx}
#     - {address: /sensors/12/state/buttonevent, operator: eq, value: '3003'}
#     created: '2016-07-23T10:43:40'
#     lasttriggered: none
#     name: Dimmer 12.3 Lights
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '5':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: KFtoQ3-VRkdgALV}
#         method: PUT
#     conditions:
#     - {address: /sensors/3/state/lastupdated, operator: dx}
#     - {address: /sensors/3/state/buttonevent, operator: eq, value: '17'}
#     created: '2016-04-29T08:51:23'
#     lasttriggered: '2016-08-06T23:48:20'
#     name: Tap 3.3
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 2
# '50':
#     actions:
#     -   address: /groups/7/action
#         body: {bri_inc: 30, transitiontime: 9}
#         method: PUT
#     -   address: /groups/8/action
#         body: {bri_inc: 30, transitiontime: 9}
#         method: PUT
#     conditions:
#     - {address: /sensors/12/state/lastupdated, operator: dx}
#     - {address: /sensors/12/state/buttonevent, operator: eq, value: '2000'}
#     created: '2016-07-23T10:43:40'
#     lasttriggered: none
#     name: Dimmer 12.2 Lights
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '51':
#     actions:
#     -   address: /groups/7/action
#         body: {bri_inc: 56, transitiontime: 9}
#         method: PUT
#     -   address: /groups/8/action
#         body: {bri_inc: 56, transitiontime: 9}
#         method: PUT
#     conditions:
#     - {address: /sensors/12/state/lastupdated, operator: dx}
#     - {address: /sensors/12/state/buttonevent, operator: eq, value: '2001'}
#     created: '2016-07-23T10:43:40'
#     lasttriggered: none
#     name: Dimmer 12.2 Lights
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '52':
#     actions:
#     -   address: /groups/7/action
#         body: {bri_inc: 0}
#         method: PUT
#     -   address: /groups/8/action
#         body: {bri_inc: 0}
#         method: PUT
#     conditions:
#     - {address: /sensors/12/state/lastupdated, operator: dx}
#     - {address: /sensors/12/state/buttonevent, operator: eq, value: '2003'}
#     created: '2016-07-23T10:43:40'
#     lasttriggered: none
#     name: Dimmer 12.2 Lights
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '53':
#     actions:
#     -   address: /groups/7/action
#         body: {'on': false}
#         method: PUT
#     -   address: /groups/8/action
#         body: {'on': false}
#         method: PUT
#     -   address: /sensors/13/state
#         body: {status: 0}
#         method: PUT
#     conditions:
#     - {address: /sensors/12/state/lastupdated, operator: dx}
#     - {address: /sensors/12/state/buttonevent, operator: eq, value: '4000'}
#     created: '2016-07-23T10:43:40'
#     lasttriggered: none
#     name: Dimmer 12.4 Lights
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '54':
#     actions:
#     -   address: /groups/4/action
#         body: {bri_inc: 0}
#         method: PUT
#     conditions:
#     - {address: /sensors/11/state/lastupdated, operator: dx}
#     - {address: /sensors/11/state/buttonevent, operator: eq, value: '3003'}
#     created: '2016-07-23T10:56:03'
#     lasttriggered: none
#     name: Dimmer 11.3 Lights
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '55':
#     actions:
#     -   address: /groups/4/action
#         body: {bri_inc: 30, transitiontime: 9}
#         method: PUT
#     conditions:
#     - {address: /sensors/11/state/lastupdated, operator: dx}
#     - {address: /sensors/11/state/buttonevent, operator: eq, value: '2000'}
#     created: '2016-07-23T10:56:03'
#     lasttriggered: none
#     name: Dimmer 11.2 Lights
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '56':
#     actions:
#     -   address: /groups/4/action
#         body: {bri_inc: 56, transitiontime: 9}
#         method: PUT
#     conditions:
#     - {address: /sensors/11/state/lastupdated, operator: dx}
#     - {address: /sensors/11/state/buttonevent, operator: eq, value: '2001'}
#     created: '2016-07-23T10:56:03'
#     lasttriggered: none
#     name: Dimmer 11.2 Lights
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '57':
#     actions:
#     -   address: /groups/4/action
#         body: {bri_inc: 0}
#         method: PUT
#     conditions:
#     - {address: /sensors/11/state/lastupdated, operator: dx}
#     - {address: /sensors/11/state/buttonevent, operator: eq, value: '2003'}
#     created: '2016-07-23T10:56:03'
#     lasttriggered: none
#     name: Dimmer 11.2 Lights
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '58':
#     actions:
#     -   address: /groups/4/action
#         body: {'on': false}
#         method: PUT
#     -   address: /sensors/14/state
#         body: {status: 0}
#         method: PUT
#     conditions:
#     - {address: /sensors/11/state/lastupdated, operator: dx}
#     - {address: /sensors/11/state/buttonevent, operator: eq, value: '4000'}
#     created: '2016-07-23T10:56:03'
#     lasttriggered: none
#     name: Dimmer 11.4 Lights
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: true
#     status: enabled
#     timestriggered: 0
# '6':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: jK3AIIkFATelYSp}
#         method: PUT
#     conditions:
#     - {address: /sensors/3/state/lastupdated, operator: dx}
#     - {address: /sensors/3/state/buttonevent, operator: eq, value: '16'}
#     created: '2016-04-29T08:51:24'
#     lasttriggered: none
#     name: Tap 3.2
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 0
# '7':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: qusSD82UJv6OIE6}
#         method: PUT
#     conditions:
#     - {address: /sensors/3/state/lastupdated, operator: dx}
#     - {address: /sensors/3/state/buttonevent, operator: eq, value: '18'}
#     created: '2016-04-29T08:51:24'
#     lasttriggered: '2016-08-05T22:37:43'
#     name: Tap 3.4
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 1
# '8':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: z7c8bEBWcHBYGA2}
#         method: PUT
#     conditions:
#     - {address: /sensors/3/state/lastupdated, operator: dx}
#     - {address: /sensors/3/state/buttonevent, operator: eq, value: '34'}
#     created: '2016-04-29T08:51:26'
#     lasttriggered: '2016-08-07T00:13:21'
#     name: Tap 3.1
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 4
# '9':
#     actions:
#     -   address: /groups/8/action
#         body: {scene: JFb70MR1pTrdTd1}
#         method: PUT
#     conditions:
#     - {address: /sensors/4/state/lastupdated, operator: dx}
#     - {address: /sensors/4/state/buttonevent, operator: eq, value: '17'}
#     created: '2016-07-23T11:48:50'
#     lasttriggered: none
#     name: Tap 4.3
#     owner: IneFZ4CIEdSQQN4oCGExhsi0cWquxMrZY6tEElKM
#     recycle: false
#     status: enabled
#     timestriggered: 0

# %% [markdown]
# Show the rules triggered by the Sitting Room switch.
#
# For Tap switches, buttons 1,2,3,4 are represented by the values 34,16,17,18 respectively.

# %%
switch = '10'  # sitting room
print "Switch {} -- {}\n".format(switch, sensors[switch]['name'])

# State changes on the switch will look like this:
state_string = "/sensors/{}/state/".format(switch)

# Look through the rules for once which contain this 
# string in their conditions:
for rid, info in rules.items():
    this_switch = False
    matching_conditions = [c for c in info['conditions'] if state_string in c['address']]
    if len(matching_conditions) > 0:
        print "{:3} {:20}".format(rid, info['name'])
        for c in info['conditions']:
            print "   ? condition {}".format(c)
        for a in info['actions']:

            # If the action involves applying a scene, get its name
            scene_name = ""
            if 'scene' in a['body']:
                scene_name = scenes[a['body']['scene']]['name']
            
            print "   - action address {} body {:16} {} ".format( a['address'], a['body'], scene_name)
# Out:
# Switch 10 -- Sitting room
#
# 29  Tap 10.3
#    ? condition {u'operator': u'dx', u'address': u'/sensors/10/state/lastupdated'}
#    ? condition {u'operator': u'eq', u'value': u'17', u'address': u'/sensors/10/state/buttonevent'}
#    - action address /groups/6/action body {u'scene': u'SUThT3XiV7sSzml'} Warm
# 31  Tap 10.4
#    ? condition {u'operator': u'dx', u'address': u'/sensors/10/state/lastupdated'}
#    ? condition {u'operator': u'eq', u'value': u'18', u'address': u'/sensors/10/state/buttonevent'}
#    - action address /groups/6/action body {u'scene': u'3owQUn01W7nVsxR'} Evening
# 30  Tap 10.2
#    ? condition {u'operator': u'dx', u'address': u'/sensors/10/state/lastupdated'}
#    ? condition {u'operator': u'eq', u'value': u'16', u'address': u'/sensors/10/state/buttonevent'}
#    - action address /groups/6/action body {u'scene': u'SePln7Lt9-H7Hm7'} Bright
# 32  Tap 10.1
#    ? condition {u'operator': u'dx', u'address': u'/sensors/10/state/lastupdated'}
#    ? condition {u'operator': u'eq', u'value': u'34', u'address': u'/sensors/10/state/buttonevent'}
#    - action address /groups/6/action body {u'scene': u'wG25IXpcHHTim4g'} Off

# %% [markdown]
# Let's see what is actually done by one of these scenes:

# %%
scene='3owQUn01W7nVsxR' # 'Evening' scene button 10.4

s = bridge.scenes[scene]()
print yaml.safe_dump(s, indent=4)
# Out:
# appdata: {data: mdVDQ_r06_d99, version: 1}
# lastupdated: '2016-08-07T09:36:40'
# lights: ['14', '21', '24', '25']
# lightstates:
#     '14':
#         bri: 189
#         'on': true
#         xy: [0.5102, 0.3642]
#     '21': {bri: 189, 'on': true}
#     '24': {bri: 128, ct: 200, 'on': true}
#     '25': {bri: 128, ct: 200, 'on': true}
# locked: true
# name: Evening
# owner: zeQomfNu-w-p1PLM8oeYTiXbtqsxn-q1-7MLIN4B
# picture: ''
# recycle: false
# version: 2
